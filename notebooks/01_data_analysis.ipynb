# %% [markdown]
# # Phase 4: Exploratory Data Analysis (EDA)
#
# This notebook performs exploratory data analysis to understand feature distributions, correlations, outliers, and key churn drivers before neural network model training.

# %%
import sys
from pathlib import Path
sys.path.append('..')

from src.eda import run_eda_pipeline

# Run complete EDA pipeline and generate figures
run_eda_pipeline()
