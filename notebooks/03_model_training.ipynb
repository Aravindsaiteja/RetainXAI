# %% [markdown]
# # Phase 7: Model Training and Experiment Tracking
#
# This notebook trains multiple neural network architectures using PyTorch, evaluates performance on validation data, tracks metrics, applies early stopping, and saves the winning model checkpoint.

# %%
import sys
from pathlib import Path
sys.path.append('..')

from src.train import run_experiment_tracking_and_training

# Run experiment tracking and save winning PyTorch model
best_model, best_history, exp_df = run_experiment_tracking_and_training()
exp_df
