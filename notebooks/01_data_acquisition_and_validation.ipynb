# %% [markdown]
# # Phase 3: Data Acquisition and Validation Notebook
#
# This notebook downloads the **IBM Telco Customer Churn** dataset and runs automated validation checks.

# %%
import sys
from pathlib import Path
import pandas as pd

# Ensure src modules can be imported
sys.path.append('..')
from src.data_validation import load_and_validate_raw_data

# Run automated acquisition & validation pipeline
df = load_and_validate_raw_data()
df.head()
