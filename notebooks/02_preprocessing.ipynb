# %% [markdown]
# # Phase 5: Data Preprocessing and Feature Engineering
#
# This notebook runs the automated feature engineering, stratified splitting, scaling, encoding, and artifact saving pipeline.

# %%
import sys
from pathlib import Path
sys.path.append('..')

from src.data_preprocessing import run_preprocessing_pipeline

# Execute pipeline
df_train, df_val, df_test, preprocessor, pos_weight = run_preprocessing_pipeline()
print('Transformed train shape:', df_train.shape)
